# %%
# --- 1. Imports ---
import pandas as pd
import numpy as np
import re
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

# Download stopwords if not already available
nltk.download("stopwords")
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\CLL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# --- 2. Load Data ---
df = pd.read_csv("../data/cleaned_scraped_reviews.csv")

print("Shape:", df.shape)
print(df.columns)

# Focus only on the 'text' column for now
texts = df['text'].dropna().tolist()
print("Sample review:\n", texts[0])
# Out:
# Shape: (3941, 13)
# Index(['Unnamed: 0', 'address', 'categories/0', 'categories/1', 'categories/2',
#        'categories/3', 'categories/4', 'categoryName', 'name',
#        'publishedAtDate', 'text', 'translatedLanguage', 'category'],
#       dtype='object')
# Sample review:
#  Learn about their history, customs, and how they lived!

# %%
# --- 3. Preprocessing ---

stop_words = set(stopwords.words("english"))

def preprocess(text):
    text = text.lower()
    text = re.sub(r"[^a-z\s]", "", text)  # keep only letters
    tokens = [w for w in text.split() if w not in stop_words and len(w) > 2]
    return " ".join(tokens)

df['clean_text'] = df['text'].dropna().apply(preprocess)
df = df.dropna(subset=['clean_text'])
df.head()
# Out:
#    Unnamed: 0                                            address categories/0  \
# 0           1  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...       Castle
# 1           3  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...       Castle
# 2           7  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...       Castle
# 3           8  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...       Castle
# 4           9  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...       Castle
#
#           categories/1             categories/2 categories/3  \
# 0  Historical landmark  Historical place museum       Museum
# 1  Historical landmark  Historical place museum       Museum
# 2  Historical landmark  Historical place museum       Museum
# 3  Historical landmark  Historical place museum       Museum
# 4  Historical landmark  Historical place museum       Museum
#
#          categories/4 categoryName               name  \
# 0  Tourist attraction       Castle              Edgar
# 1  Tourist attraction       Castle   Cecilia Figueroa
# 2  Tourist attraction       Castle        Luis Spirit
# 3  Tourist attraction       Castle  Juliana Rosenhave
# 4  Tourist attraction       Castle             DANIEL
#
#             publishedAtDate  \
# 0  2025-08-27T11:31:55.424Z
# 1  2025-08-27T03:40:13.279Z
# 2  2025-08-26T23:49:24.207Z
# 3  2025-08-26T22:59:59.030Z
# 4  2025-08-26T21:57:10.257Z
#
#                                                 text translatedLanguage  \
# 0  Learn about their history, customs, and how th...                 en
# 1  If you like the history of Mexico or in genera...                 en
# 2  Excellent place to visit with the family, enjo...                 en
# 3  It's extremely touristy but worth it. Great vi...                NaN
# 4                          spectacular beyond words.                 en
#
#    category                                         clean_text
# 0       NaN                        learn history customs lived
# 1       NaN  like history mexico general good idea come eve...
# 2       NaN  excellent place visit family enjoy history sce...
# 3       NaN          extremely touristy worth great views city
# 4       NaN                           spectacular beyond words

# %%
# --- 4. TF-IDF Vectorization ---
vectorizer = TfidfVectorizer(
    max_df=0.8,   # ignore words that appear in >80% docs
    min_df=5,     # ignore words that appear in <5 docs
    stop_words='english'
)

X = vectorizer.fit_transform(df['clean_text'])
print("TF-IDF matrix shape:", X.shape)
# Out:
# TF-IDF matrix shape: (3941, 1542)

# %%
# --- 5. Topic Modeling (NMF) ---
num_topics = 20  # start with 8, we can tune later
nmf = NMF(n_components=num_topics, random_state=42)
nmf.fit(X)

feature_names = vectorizer.get_feature_names_out()

def display_topics(model, feature_names, no_top_words):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx}:")
        print(" | ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print()

display_topics(nmf, feature_names, 10)
# Out:
# Topic 0:
# good | attention | price | atmosphere | prices | seasoning | taste | quality | cheap | rich
#
# Topic 1:
# excellent | family | location | attention | view | prices | option | restaurant | atmosphere | cathedral
#
# Topic 2:
# beautiful | architecture | cathedral | view | square | views | oaxaca | free | worth | tour
#
# Topic 3:
# service | attention | attentive | flavor | customer | terrible | quick | speed | tasty | loved
#
# Topic 4:
# place | visit | family | history | walk | enjoy | wonderful | incredible | emblematic | spend
#
# Topic 5:
# fast | friendly | efficient | prices | rich | clean | attentive | tasty | quite | affordable
#
# Topic 6:
# delicious | friendly | flutes | dinner | views | cheap | flan | dishes | quick | wait
#
# Topic 7:
# nice | walk | clean | museum | worth | really | safe | tasty | pretty | experience
#
# Topic 8:
# city | mexico | visit | history | center | historic | mustsee | heart | zcalo | cathedral
#
# Topic 9:
# like | time | dont | order | house | toos | didnt | bad | really | long
#
# Topic 10:
# food | mexican | atmosphere | quality | drinks | tasty | restaurant | prices | expensive | quickly
#
# Topic 11:
# great | tacos | atmosphere | drinks | view | history | museum | fun | location | kids
#
# Topic 12:
# love | tacos | house | going | toos | serve | architecture | want | come | cochinita
#
# Topic 13:
# staff | hotel | friendly | location | wonderful | breakfast | clean | attentive | stay | room
#
# Topic 14:
# pozole | best | tacos | mexican | ive | taste | restaurant | tastes | thing | quality
#
# Topic 15:
# super | attentive | cool | cute | serve | friendly | tacos | crowded | quickly | quality
#
# Topic 16:
# recommended | highly | recommend | experience | flautas | unique | history | learn | totally | aspects
#
# Topic 17:
# people | lot | wait | lots | history | long | walk | waiting | station | thing
#
# Topic 18:
# amazing | view | experience | incredible | views | worth | toronto | expensive | spectacular | recommend
#
# Topic 19:
# eat | places | option | tasty | cheap | prices | little | quickly | houses | weekends

# %%
# --- 6. Assign topics back to reviews ---
topic_values = nmf.transform(X)
df['topic'] = topic_values.argmax(axis=1)

df[['text', 'topic']].head(20)
# Out:
#                                                  text  topic
# 0   Learn about their history, customs, and how th...      8
# 1   If you like the history of Mexico or in genera...     17
# 2   Excellent place to visit with the family, enjo...      1
# 3   It's extremely touristy but worth it. Great vi...     11
# 4                           spectacular beyond words.     18
# 5   Reasonably well maintained, despite government...      8
# 6                                                  ✌🏽      0
# 7         A beautiful place, the views are unmissable      2
# 8              One of the best museums I've been to✨✨     14
# 9    It is a very nice place to visit with the family      7
# 10             Excellent food, service and nice place      7
# 11                                     Amazing castle     18
# 12                                    Beautiful place      2
# 13  It's very crowded on weekends, especially in t...      9
# 14                                          Beautiful      2
# 15  On weekends, it's so crowded that you can't re...     11
# 16           A journey through the history of Mexico.      8
# 17                     A great experience on the tour     11
# 18                                             Superb     18
# 19  A beautiful place steeped in history. Its gard...      8

# %%
# --- Reorder columns so that: address | topic | text | (rest) ---

# Make sure topic column exists (empty for now, will be filled after modeling)
if "topic" not in df.columns:
    df["topic"] = None

# Reorder logic
front_cols = ["address", "topic", "text"]
other_cols = [col for col in df.columns if col not in front_cols]

# Reordered DataFrame
df = df[front_cols + other_cols]

df.head(10)
# Out:
#                                              address  topic  \
# 0  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...      8
# 1  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...     17
# 2  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...      1
# 3  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...     11
# 4  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...     18
# 5  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...      8
# 6  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...      0
# 7  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...      2
# 8  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...     14
# 9  Bosque de Chapultepec I Secc, Miguel Hidalgo, ...      7
#
#                                                 text  Unnamed: 0 categories/0  \
# 0  Learn about their history, customs, and how th...           1       Castle
# 1  If you like the history of Mexico or in genera...           3       Castle
# 2  Excellent place to visit with the family, enjo...           7       Castle
# 3  It's extremely touristy but worth it. Great vi...           8       Castle
# 4                          spectacular beyond words.           9       Castle
# 5  Reasonably well maintained, despite government...          11       Castle
# 6                                                 ✌🏽          14       Castle
# 7        A beautiful place, the views are unmissable          17       Castle
# 8             One of the best museums I've been to✨✨          19       Castle
# 9   It is a very nice place to visit with the family          20       Castle
#
#           categories/1             categories/2 categories/3  \
# 0  Historical landmark  Historical place museum       Museum
# 1  Historical landmark  Historical place museum       Museum
# 2  Historical landmark  Historical place museum       Museum
# 3  Historical landmark  Historical place museum       Museum
# 4  Historical landmark  Historical place museum       Museum
# 5  Historical landmark  Historical place museum       Museum
# 6  Historical landmark  Historical place museum       Museum
# 7  Historical landmark  Historical place museum       Museum
# 8  Historical landmark  Historical place museum       Museum
# 9  Historical landmark  Historical place museum       Museum
#
#          categories/4 categoryName               name  \
# 0  Tourist attraction       Castle              Edgar
# 1  Tourist attraction       Castle   Cecilia Figueroa
# 2  Tourist attraction       Castle        Luis Spirit
# 3  Tourist attraction       Castle  Juliana Rosenhave
# 4  Tourist attraction       Castle             DANIEL
# 5  Tourist attraction       Castle   Jose Luis Flores
# 6  Tourist attraction       Castle       Corky Jordan
# 7  Tourist attraction       Castle     Angel Aguilera
# 8  Tourist attraction       Castle     Miriel Malvaez
# 9  Tourist attraction       Castle    Arantza Noriega
#
#             publishedAtDate translatedLanguage  category  \
# 0  2025-08-27T11:31:55.424Z                 en       NaN
# 1  2025-08-27T03:40:13.279Z                 en       NaN
# 2  2025-08-26T23:49:24.207Z                 en       NaN
# 3  2025-08-26T22:59:59.030Z                NaN       NaN
# 4  2025-08-26T21:57:10.257Z                 en       NaN
# 5  2025-08-26T21:20:36.730Z                 en       NaN
# 6  2025-08-26T17:30:22.328Z                NaN       NaN
# 7  2025-08-26T06:36:08.906Z                 en       NaN
# 8  2025-08-26T04:34:29.320Z                 en       NaN
# 9  2025-08-26T03:21:58.974Z                 en       NaN
#
#                                           clean_text
# 0                        learn history customs lived
# 1  like history mexico general good idea come eve...
# 2  excellent place visit family enjoy history sce...
# 3          extremely touristy worth great views city
# 4                           spectacular beyond words
# 5  reasonably well maintained despite government ...
# 6
# 7                   beautiful place views unmissable
# 8                               one best museums ive
# 9                            nice place visit family

# %%
# --- 7. Save outputs ---
df.to_csv("../data/reviews_with_topics.csv", index=False)
